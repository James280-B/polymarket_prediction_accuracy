# %%
from scr.data_handler.poly_data_handler import PolyDataHandler
from scr.poly_prob_model.compute_poly_prob_accuracy import ComputePolyProbAccuracy

# %%
num_markets = 20
input_labels = ["investing"]
resolution = 1440
horizon = "1w"


data = PolyDataHandler(num_markets=num_markets, input_labels=input_labels, resolution=resolution, horizon=horizon)
data_sets = data.build_data_set()
data_sets.head()
print(data_sets)

# %%
num_markets = 20
input_labels = ["investing", "lockdown", "llm", "Israel", "investment", "investments"]
resolution = 1440
horizon = "1w"

prob_computer = ComputePolyProbAccuracy(num_markets=num_markets, input_labels=input_labels, resolution=resolution, horizon=horizon)
avg_prob = prob_computer.run()
print(avg_prob)
# Out:
# {'data': {'condition': {'id': '0x5a571616829a3a9d79947482633f87b6f49eab631d97125d9b3e8264a75958bb', 'positionIds': ['31605619173990498388070884654167460722317064064230231519860421864071285155753', '3544414520775547881964652175189646649857111640793461305677318859811704292211'], 'payoutNumerators': ['0', '1'], 'payoutDenominator': '1'}}}
# market 0 data completed
# {'data': {'condition': {'id': '0xd0f7da12e595d257996f3c0bcfa60e5b5f166eb554554c81560d96c97dc52b55', 'positionIds': ['18693144468480106003472923918272491903381294753748795710461251577011539020407', '46877704938315040345800884095745117989382029524381763043287779821909305610650'], 'payoutNumerators': ['0', '1'], 'payoutDenominator': '1'}}}
# market 1 data completed
# ...
